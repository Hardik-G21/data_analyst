# %% [markdown]
# Insight Identification:
#
# When filtering the dashboard to the Tech category:
# In the first 3 months (Jan–Mar), revenue is relatively lower and stable.
# In the last 3 months (May–Jul), revenue shows a clear increase with higher values.
#
# Insight:
# The Tech category experiences significant growth in the later months, indicating increased demand, better marketing performance, or improved user engagement over time.

# %% [markdown]
# Reflection:
#
# If a sharp revenue spike is observed in a specific region for a particular category, I would investigate external factors such as local holidays, seasonal trends, weather conditions, promotional campaigns, and competitor activities. These factors can strongly influence customer behavior and help explain sudden anomalies in revenue patterns.
